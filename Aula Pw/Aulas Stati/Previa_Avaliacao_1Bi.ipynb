# %% [markdown]
# # 📝 Prévia da Avaliação 1º Bimestre

# %% [markdown]
# ## ✅ Parte 1 – Questões Objetivas e Teóricas
# ### Questões estão disponíveis no AVA (5 pontos)

# %% [markdown]
# ## 🔧 Parte 2 – Prática Google Colab
#
# ### Informe seu nome e RA

# %%
usuario = input("Digite seu nome: ")
print("Nome do aluno:", usuario)
RA = input("Digite seu RA: ")
print("RA do aluno:", RA)
# Out:
# Digite seu nome: Marcelo
# Nome do aluno: Marcelo
# Digite seu RA: 1231231
# RA do aluno: 1231231

# %% [markdown]
# **1. (0,5 pontos) Carregue o dataset Titanic e exiba as 5 primeiras linhas.**

# %% [markdown]
# **2. (1 ponto) Verifique se há valores ausentes e mostre o total por coluna.**

# %% [markdown]
# **3. (1 ponto) Preencha os valores ausentes de 'Age' com a média da coluna.**

# %% [markdown]
# **4. (1 ponto) Crie uma coluna que classifica os passageiros por faixa de tarifa paga (Fare), agrupando em faixas:**
# - Baixa:   entre 0 e 20
# - Média:   entre 20 e 50
# - Alta:    entre 50 e 100
# - Muito Alta: acima de 100

# %% [markdown]
# **5. (1 ponto) Crie um gráfico que apresente a Taxa de Sobrevivência por Faixa de Tarifa**

# %% [markdown]
# **6. (0,5 pontos) Explicação do Insight:**
#
# Escreva aqui sua interpretação dos dados a partir do gráfico criado.
